# %% [markdown]
# # Task 1: Archiving the Company Listing
# The purpose of this task is to scrape the Company Registration Office (CRO) website for company details and store them in a MySQL database. We will retrieve information for registration numbers ranging from 1 to 337078.
#
# Source: 'https://application.ocr.gov.np/faces/CompanyDetails.jsp'

# %%
import asyncio
import aiohttp
import logging
from bs4 import BeautifulSoup
import aiomysql
from datetime import datetime

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Function to validate date
def validate_date(date_text):
    if date_text:
        try:
            return datetime.strptime(date_text, '%Y-%m-%d').date()
        except ValueError:
            return None
    return None

# %%
async def create_pool():
    try:
        pool = await aiomysql.create_pool(
            host="localhost",
            port=3306,
            user="root",
            password="Mysql@2024",
            db="employers_rating",
            autocommit=True,
            auth_plugin='mysql_native_password',
            minsize=1,
            maxsize=10
        )
        logging.info("Database connection pool created successfully")
        return pool
    except aiomysql.Error as err:
        logging.error(f"Database connection error: {err}")
        return None

# %%
async def create_table_if_not_exists(pool):
    async with pool.acquire() as conn:
        async with conn.cursor() as cursor:
            await cursor.execute("""
            CREATE TABLE IF NOT EXISTS company_master (
                COMPANY_ID INT AUTO_INCREMENT PRIMARY KEY,
                CRO_SN INT,
                CRO_Nepali_Name VARCHAR(255),
                CRO_English_Name VARCHAR(2555),
                CRO_Registration_Number INT UNIQUE,
                CRO_Registration_Date_BS DATE,
                CRO_Company_Type VARCHAR(255),
                CRO_Company_Address VARCHAR(255),
                CRO_Recent_Communication_With_OCR DATE
            )
            """)

# %%
async def insert_or_update_data(pool, data):
    async with pool.acquire() as conn:
        async with conn.cursor() as cursor:
            await cursor.execute("""
            INSERT INTO company_master (CRO_SN, CRO_Nepali_Name, CRO_English_Name, CRO_Registration_Number, CRO_Registration_Date_BS, CRO_Company_Type, CRO_Company_Address, CRO_Recent_Communication_With_OCR)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
            ON DUPLICATE KEY UPDATE
            CRO_SN = VALUES(CRO_SN),
            CRO_Nepali_Name = VALUES(CRO_Nepali_Name),
            CRO_English_Name = VALUES(CRO_English_Name),
            CRO_Registration_Date_BS = VALUES(CRO_Registration_Date_BS),
            CRO_Company_Type = VALUES(CRO_Company_Type),
            CRO_Company_Address = VALUES(CRO_Company_Address),
            CRO_Recent_Communication_With_OCR = VALUES(CRO_Recent_Communication_With_OCR)
            """, data)

# %%
HEADERS = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'en-US,en;q=0.9',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}

url = 'https://application.ocr.gov.np/faces/CompanyDetails.jsp'

# %%
async def submit_form_and_process(session, registration_number, pool):
    try:
        async with session.get(url, headers=HEADERS, ssl=False) as response:
            response.raise_for_status()
            soup = BeautifulSoup(await response.text(), 'html.parser')
            form = soup.find('form')

            if not form:
                logging.warning("Form not found in the page.")
                return

            action = form.get('action')
            if not action:
                logging.warning("Form action attribute not found.")
                return

            action_url = url if action.startswith('/') else url + action

            payload = {input_field.get('name'): input_field.get('value', '') for input_field in form.find_all('input')}
            payload['j_id_jsp_826405674_6:registrationNumber'] = str(registration_number)

            logging.info(f"Submitting form to {action_url} with payload: {payload}")

            async with session.post(action_url, data=payload, headers=HEADERS, ssl=False) as post_response:
                post_response.raise_for_status()
                logging.info(f"Form submitted successfully for registration number {registration_number}.")

                soup = BeautifulSoup(await post_response.text(), 'html.parser')
                table = soup.find('table', {'id': 'j_id_jsp_826405674_6:companyDetails'})

                if table:
                    rows = table.find_all('tr')
                    for row in rows:
                        cols = row.find_all('td')
                        if len(cols) == 8:
                            data = [col.text.strip() if col.text.strip() != '' else None for col in cols]
                            data[4] = validate_date(data[4]) if data[4] else None
                            data[7] = validate_date(data[7]) if data[7] else None

                            await insert_or_update_data(pool, data)
                            logging.info("Data inserted or updated successfully.")
                else:
                    logging.warning(f"Table not found in the response for registration number {registration_number}.")
    except aiohttp.ClientError as e:
        logging.error(f"HTTP request error for registration number {registration_number}: {e}")
    except aiohttp.ClientConnectionError as e:
        logging.error(f"Connection error for registration number {registration_number}: {e}")
    except aiomysql.Error as e:
        logging.error(f"Database error for registration number {registration_number}: {e}")
    except Exception as e:
        logging.error(f"Unexpected error for registration number {registration_number}: {e}")

# %%
async def main():
    pool = await create_pool()
    if pool:
        await create_table_if_not_exists(pool)

        async with aiohttp.ClientSession(cookie_jar=aiohttp.CookieJar()) as session:
            tasks = []
            for reg_num in range(1, 337078):  
                task = submit_form_and_process(session, reg_num, pool)
                tasks.append(task)
                if len(tasks) % 10 == 0:  # Adjust this number as needed
                    await asyncio.gather(*tasks)
                    tasks = []

            if tasks:
                await asyncio.gather(*tasks)

        pool.close()
        await pool.wait_closed()
        logging.info("Database connection pool closed.")

# Run the main function in Jupyter notebook
await main()
# Out:
# 2024-07-10 13:31:37,431 - INFO - Database connection pool created successfully
# C:\Users\KIIT01\anaconda3\Lib\site-packages\aiomysql\cursors.py:239: Warning: Table 'company_master' already exists
#   await self._query(query)
# 2024-07-10 13:31:37,772 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27621:j_id27622'}
# 2024-07-10 13:31:37,777 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '1', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27623:j_id27624'}
# 2024-07-10 13:31:37,782 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '4', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27625:j_id27626'}
# 2024-07-10 13:31:37,793 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '5', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27627:j_id27628'}
# 2024-07-10 13:31:37,801 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '6', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27629:j_id27630'}
# 2024-07-10 13:31:37,807 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '3', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27633:j_id27634'}
# 2024-07-10 13:31:37,814 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '7', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27631:j_id27632'}
# 2024-07-10 13:31:37,819 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '8', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27637:j_id27638'}
# 2024-07-10 13:31:37,825 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '10', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27635:j_id27636'}
# 2024-07-10 13:31:37,833 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '9', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27639:j_id27640'}
# 2024-07-10 13:31:37,930 - INFO - Form submitted successfully for registration number 1.
# 2024-07-10 13:31:37,956 - INFO - Form submitted successfully for registration number 5.
# 2024-07-10 13:31:37,958 - INFO - Form submitted successfully for registration number 2.
# 2024-07-10 13:31:37,996 - INFO - Form submitted successfully for registration number 4.
# 2024-07-10 13:31:37,998 - INFO - Form submitted successfully for registration number 7.
# 2024-07-10 13:31:38,028 - INFO - Form submitted successfully for registration number 3.
# 2024-07-10 13:31:38,040 - INFO - Form submitted successfully for registration number 8.
# 2024-07-10 13:31:38,049 - INFO - Form submitted successfully for registration number 10.
# 2024-07-10 13:31:38,062 - INFO - Form submitted successfully for registration number 6.
# C:\Users\KIIT01\anaconda3\Lib\site-packages\aiomysql\cursors.py:239: Warning: 'VALUES function' is deprecated and will be removed in a future release. Please use an alias (INSERT INTO ... VALUES (...) AS alias) and replace VALUES(col) in the ON DUPLICATE KEY UPDATE clause with alias.col instead
#   await self._query(query)
# 2024-07-10 13:31:38,070 - INFO - Form submitted successfully for registration number 9.
# 2024-07-10 13:31:38,095 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,097 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,099 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,100 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,102 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,103 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,106 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,107 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,108 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,114 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,117 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,118 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,119 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,122 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,123 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,128 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,129 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,131 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,133 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,140 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,142 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,143 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,143 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,145 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,146 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,148 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,152 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,154 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,156 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,158 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,165 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,166 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,167 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,168 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,169 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,170 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,172 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,176 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,177 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,179 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,180 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,187 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,189 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,189 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,190 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,191 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,192 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,193 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,195 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,197 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,199 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,203 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,205 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,206 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,208 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,209 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,211 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,213 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,217 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,220 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,222 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,223 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,224 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,225 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,227 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,230 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,231 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,233 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,234 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,236 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,237 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,238 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,239 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,243 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,247 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,252 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,256 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,275 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '14', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27656:j_id27657'}
# 2024-07-10 13:31:38,280 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '15', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27654:j_id27655'}
# 2024-07-10 13:31:38,287 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '18', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27658:j_id27659'}
# 2024-07-10 13:31:38,292 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '12', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27652:j_id27653'}
# 2024-07-10 13:31:38,299 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '19', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27660:j_id27661'}
# 2024-07-10 13:31:38,307 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '20', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27662:j_id27663'}
# 2024-07-10 13:31:38,319 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '11', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27664:j_id27665'}
# 2024-07-10 13:31:38,336 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '13', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27666:j_id27667'}
# 2024-07-10 13:31:38,342 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '17', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27670:j_id27671'}
# 2024-07-10 13:31:38,351 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '16', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27668:j_id27669'}
# 2024-07-10 13:31:38,404 - INFO - Form submitted successfully for registration number 14.
# 2024-07-10 13:31:38,412 - INFO - Form submitted successfully for registration number 15.
# 2024-07-10 13:31:38,435 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,438 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,440 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,443 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,445 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,447 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,449 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,451 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,455 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,459 - INFO - Form submitted successfully for registration number 11.
# 2024-07-10 13:31:38,460 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,475 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,479 - INFO - Form submitted successfully for registration number 17.
# 2024-07-10 13:31:38,480 - INFO - Form submitted successfully for registration number 16.
# 2024-07-10 13:31:38,481 - INFO - Form submitted successfully for registration number 12.
# 2024-07-10 13:31:38,482 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,487 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,491 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,495 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,527 - INFO - Form submitted successfully for registration number 18.
# 2024-07-10 13:31:38,540 - INFO - Form submitted successfully for registration number 19.
# 2024-07-10 13:31:38,553 - INFO - Form submitted successfully for registration number 20.
# 2024-07-10 13:31:38,567 - INFO - Form submitted successfully for registration number 13.
# 2024-07-10 13:31:38,580 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,581 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,583 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,584 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,585 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,587 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,590 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,591 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,592 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,594 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,596 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,598 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,600 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,602 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,603 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,606 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,608 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,609 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,612 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,613 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,615 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,617 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,618 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,620 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,622 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,624 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,625 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,628 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,630 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,631 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,633 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,634 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,636 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,638 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,640 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,642 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,643 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,644 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,646 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,647 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,650 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,652 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,658 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,662 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,666 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,691 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '24', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27684:j_id27685'}
# 2024-07-10 13:31:38,702 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '23', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27682:j_id27683'}
# 2024-07-10 13:31:38,708 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '27', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27686:j_id27687'}
# 2024-07-10 13:31:38,714 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '29', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27688:j_id27689'}
# 2024-07-10 13:31:38,720 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '21', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27690:j_id27691'}
# 2024-07-10 13:31:38,724 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '30', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27696:j_id27697'}
# 2024-07-10 13:31:38,728 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '28', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27698:j_id27699'}
# 2024-07-10 13:31:38,734 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '25', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27692:j_id27693'}
# 2024-07-10 13:31:38,737 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '22', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27694:j_id27695'}
# 2024-07-10 13:31:38,745 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '26', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27700:j_id27701'}
# 2024-07-10 13:31:38,828 - INFO - Form submitted successfully for registration number 24.
# 2024-07-10 13:31:38,843 - INFO - Form submitted successfully for registration number 23.
# 2024-07-10 13:31:38,852 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,854 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,856 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,858 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,861 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,863 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,865 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,869 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,897 - INFO - Form submitted successfully for registration number 28.
# 2024-07-10 13:31:38,907 - INFO - Form submitted successfully for registration number 26.
# 2024-07-10 13:31:38,918 - INFO - Form submitted successfully for registration number 29.
# 2024-07-10 13:31:38,929 - INFO - Form submitted successfully for registration number 22.
# 2024-07-10 13:31:38,955 - INFO - Form submitted successfully for registration number 27.
# 2024-07-10 13:31:38,966 - INFO - Form submitted successfully for registration number 21.
# 2024-07-10 13:31:38,967 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,968 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,970 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,972 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,986 - INFO - Form submitted successfully for registration number 25.
# 2024-07-10 13:31:38,988 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,997 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:38,999 - INFO - Form submitted successfully for registration number 30.
# 2024-07-10 13:31:39,015 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,027 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,030 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,032 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,034 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,035 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,037 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,039 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,042 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,044 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,048 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,051 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,054 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,057 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,060 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,061 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,063 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,064 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,066 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,068 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,070 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,072 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,075 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,075 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,077 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,079 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,080 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,081 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,082 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,082 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,085 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,089 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,111 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '32', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27717:j_id27718'}
# 2024-07-10 13:31:39,116 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '36', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27715:j_id27716'}
# 2024-07-10 13:31:39,122 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '35', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27713:j_id27714'}
# 2024-07-10 13:31:39,127 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '38', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27719:j_id27720'}
# 2024-07-10 13:31:39,132 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '34', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27721:j_id27722'}
# 2024-07-10 13:31:39,139 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '33', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27723:j_id27724'}
# 2024-07-10 13:31:39,144 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '31', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27725:j_id27726'}
# 2024-07-10 13:31:39,152 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '37', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27727:j_id27728'}
# 2024-07-10 13:31:39,160 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '39', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27729:j_id27730'}
# 2024-07-10 13:31:39,165 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '40', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27731:j_id27732'}
# 2024-07-10 13:31:39,270 - INFO - Form submitted successfully for registration number 32.
# 2024-07-10 13:31:39,272 - INFO - Form submitted successfully for registration number 36.
# 2024-07-10 13:31:39,273 - INFO - Form submitted successfully for registration number 34.
# 2024-07-10 13:31:39,303 - INFO - Form submitted successfully for registration number 38.
# 2024-07-10 13:31:39,304 - INFO - Form submitted successfully for registration number 35.
# 2024-07-10 13:31:39,323 - INFO - Form submitted successfully for registration number 33.
# 2024-07-10 13:31:39,343 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,346 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,364 - INFO - Form submitted successfully for registration number 37.
# 2024-07-10 13:31:39,373 - INFO - Form submitted successfully for registration number 39.
# 2024-07-10 13:31:39,375 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,387 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,389 - INFO - Form submitted successfully for registration number 31.
# 2024-07-10 13:31:39,404 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,405 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,406 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,408 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,410 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,412 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,414 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,416 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,419 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,420 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,421 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,423 - INFO - Form submitted successfully for registration number 40.
# 2024-07-10 13:31:39,425 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,426 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,442 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,444 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,445 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,452 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,453 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,454 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,455 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,456 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,458 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,458 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,459 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,461 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,463 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,465 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,467 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,469 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,473 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,474 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,476 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,477 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,479 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,481 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,483 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,488 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,489 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,490 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,491 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,493 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,494 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,496 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,498 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,499 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,501 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,503 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,505 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,506 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,507 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,508 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,510 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,511 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,513 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,517 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,533 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '42', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27746:j_id27747'}
# 2024-07-10 13:31:39,540 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '43', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27750:j_id27751'}
# 2024-07-10 13:31:39,546 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '44', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27748:j_id27749'}
# 2024-07-10 13:31:39,552 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '45', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27752:j_id27753'}
# 2024-07-10 13:31:39,557 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '41', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27744:j_id27745'}
# 2024-07-10 13:31:39,563 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '49', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27754:j_id27755'}
# 2024-07-10 13:31:39,569 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '48', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27758:j_id27759'}
# 2024-07-10 13:31:39,574 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '47', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27756:j_id27757'}
# 2024-07-10 13:31:39,579 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '46', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27760:j_id27761'}
# 2024-07-10 13:31:39,585 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '50', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27762:j_id27763'}
# 2024-07-10 13:31:39,677 - INFO - Form submitted successfully for registration number 42.
# 2024-07-10 13:31:39,691 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,696 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,701 - INFO - Form submitted successfully for registration number 45.
# 2024-07-10 13:31:39,702 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,708 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,709 - INFO - Form submitted successfully for registration number 43.
# 2024-07-10 13:31:39,724 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,727 - INFO - Form submitted successfully for registration number 47.
# 2024-07-10 13:31:39,745 - INFO - Form submitted successfully for registration number 50.
# 2024-07-10 13:31:39,747 - INFO - Form submitted successfully for registration number 48.
# 2024-07-10 13:31:39,765 - INFO - Form submitted successfully for registration number 44.
# 2024-07-10 13:31:39,794 - INFO - Form submitted successfully for registration number 46.
# 2024-07-10 13:31:39,806 - INFO - Form submitted successfully for registration number 41.
# 2024-07-10 13:31:39,815 - INFO - Form submitted successfully for registration number 49.
# 2024-07-10 13:31:39,828 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,831 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,834 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,835 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,837 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,838 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,841 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,842 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,845 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,848 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,850 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,851 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,853 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,855 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,856 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,858 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,861 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,863 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,864 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,865 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,867 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,868 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,872 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,873 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,875 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,877 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,879 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,880 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,882 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,883 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,886 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,888 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,890 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,891 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,893 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,895 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,896 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,898 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,900 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,902 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,903 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,904 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,906 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,908 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,908 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,910 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,912 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,914 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,915 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,917 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,919 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,921 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,921 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,923 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,925 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,926 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,928 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,929 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,931 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,936 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:39,956 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '56', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27778:j_id27779'}
# 2024-07-10 13:31:39,966 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '59', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27780:j_id27781'}
# 2024-07-10 13:31:39,985 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '52', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27776:j_id27777'}
# 2024-07-10 13:31:39,992 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '51', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27782:j_id27783'}
# 2024-07-10 13:31:39,999 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '57', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27774:j_id27775'}
# 2024-07-10 13:31:40,005 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '55', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27786:j_id27787'}
# 2024-07-10 13:31:40,010 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '60', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27784:j_id27785'}
# 2024-07-10 13:31:40,014 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '53', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27788:j_id27789'}
# 2024-07-10 13:31:40,019 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '54', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27790:j_id27791'}
# 2024-07-10 13:31:40,025 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '58', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id27792:j_id27793'}
# 2024-07-10 13:31:40,097 - INFO - Form submitted successfully for registration number 56.
# 2024-07-10 13:31:40,119 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:40,122 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:40,126 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:40,131 - INFO - Form submitted successfully for registration number 52.
# 2024-07-10 13:31:40,132 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:40,135 - INFO - Form submitted successfully for registration number 51.
# 2024-07-10 13:31:40,146 - INFO - Form submitted successfully for registration number 59.
# 2024-07-10 13:31:40,169 - INFO - Form submitted successfully for registration number 54.
# 2024-07-10 13:31:40,170 - INFO - Form submitted successfully for registration number 57.
# 2024-07-10 13:31:40,195 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:40,196 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:40,199 - INFO - Form submitted successfully for registration number 58.
# 2024-07-10 13:31:40,216 - INFO - Form submitted successfully for registration number 60.
# 2024-07-10 13:31:40,217 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:40,219 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:40,235 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:31:40,236 - INFO - Data inserted or updated successfully.
# ...
# 2024-07-10 13:33:09,846 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2436', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id34957:j_id34958'}
# 2024-07-10 13:33:09,849 - INFO - Form submitted successfully for registration number 2431.
# 2024-07-10 13:33:09,866 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,046 - INFO - Form submitted successfully for registration number 2436.
# 2024-07-10 13:33:10,052 - INFO - Form submitted successfully for registration number 2440.
# 2024-07-10 13:33:10,053 - INFO - Form submitted successfully for registration number 2432.
# 2024-07-10 13:33:10,056 - INFO - Form submitted successfully for registration number 2438.
# 2024-07-10 13:33:10,058 - INFO - Form submitted successfully for registration number 2433.
# 2024-07-10 13:33:10,059 - INFO - Form submitted successfully for registration number 2434.
# 2024-07-10 13:33:10,060 - INFO - Form submitted successfully for registration number 2439.
# 2024-07-10 13:33:10,062 - INFO - Form submitted successfully for registration number 2437.
# 2024-07-10 13:33:10,063 - INFO - Form submitted successfully for registration number 2435.
# 2024-07-10 13:33:10,161 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,163 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,164 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,166 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,166 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,167 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,168 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,171 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,172 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,190 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2442', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id34979:j_id34980'}
# 2024-07-10 13:33:10,200 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2441', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id34981:j_id34982'}
# 2024-07-10 13:33:10,207 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2443', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id34983:j_id34984'}
# 2024-07-10 13:33:10,213 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2444', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id34985:j_id34986'}
# 2024-07-10 13:33:10,220 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2445', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id34987:j_id34988'}
# 2024-07-10 13:33:10,229 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2446', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id34991:j_id34992'}
# 2024-07-10 13:33:10,242 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2447', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id34989:j_id34990'}
# 2024-07-10 13:33:10,249 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2449', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id34995:j_id34996'}
# 2024-07-10 13:33:10,258 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2448', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id34993:j_id34994'}
# 2024-07-10 13:33:10,266 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2450', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id34997:j_id34998'}
# 2024-07-10 13:33:10,324 - INFO - Form submitted successfully for registration number 2442.
# 2024-07-10 13:33:10,340 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,351 - INFO - Form submitted successfully for registration number 2445.
# 2024-07-10 13:33:10,369 - INFO - Form submitted successfully for registration number 2441.
# 2024-07-10 13:33:10,372 - INFO - Form submitted successfully for registration number 2443.
# 2024-07-10 13:33:10,384 - INFO - Form submitted successfully for registration number 2446.
# 2024-07-10 13:33:10,409 - INFO - Form submitted successfully for registration number 2444.
# 2024-07-10 13:33:10,422 - INFO - Form submitted successfully for registration number 2449.
# 2024-07-10 13:33:10,432 - INFO - Form submitted successfully for registration number 2448.
# 2024-07-10 13:33:10,445 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,446 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,447 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,448 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,451 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,452 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,453 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,456 - INFO - Form submitted successfully for registration number 2447.
# 2024-07-10 13:33:10,486 - INFO - Form submitted successfully for registration number 2450.
# 2024-07-10 13:33:10,506 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,509 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,532 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2451', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35009:j_id35010'}
# 2024-07-10 13:33:10,542 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2452', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35011:j_id35012'}
# 2024-07-10 13:33:10,553 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2453', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35013:j_id35014'}
# 2024-07-10 13:33:10,566 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2454', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35015:j_id35016'}
# 2024-07-10 13:33:10,579 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2455', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35017:j_id35018'}
# 2024-07-10 13:33:10,589 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2456', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35019:j_id35020'}
# 2024-07-10 13:33:10,603 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2457', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35021:j_id35022'}
# 2024-07-10 13:33:10,612 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2458', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35023:j_id35024'}
# 2024-07-10 13:33:10,625 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2459', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35025:j_id35026'}
# 2024-07-10 13:33:10,635 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2460', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35027:j_id35028'}
# 2024-07-10 13:33:10,662 - INFO - Form submitted successfully for registration number 2451.
# 2024-07-10 13:33:10,677 - INFO - Form submitted successfully for registration number 2452.
# 2024-07-10 13:33:10,696 - INFO - Form submitted successfully for registration number 2454.
# 2024-07-10 13:33:10,708 - INFO - Form submitted successfully for registration number 2453.
# 2024-07-10 13:33:10,719 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,722 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,723 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,725 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,763 - INFO - Form submitted successfully for registration number 2458.
# 2024-07-10 13:33:10,765 - INFO - Form submitted successfully for registration number 2457.
# 2024-07-10 13:33:10,767 - INFO - Form submitted successfully for registration number 2460.
# 2024-07-10 13:33:10,769 - INFO - Form submitted successfully for registration number 2456.
# 2024-07-10 13:33:10,811 - INFO - Form submitted successfully for registration number 2459.
# 2024-07-10 13:33:10,824 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,826 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,828 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,829 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,831 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,834 - INFO - Form submitted successfully for registration number 2455.
# 2024-07-10 13:33:10,850 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:10,873 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2461', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35039:j_id35040'}
# 2024-07-10 13:33:10,884 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2463', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35043:j_id35044'}
# 2024-07-10 13:33:10,892 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2462', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35041:j_id35042'}
# 2024-07-10 13:33:10,899 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2465', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35045:j_id35046'}
# 2024-07-10 13:33:10,907 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2466', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35047:j_id35048'}
# 2024-07-10 13:33:10,913 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2464', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35049:j_id35050'}
# 2024-07-10 13:33:10,921 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2469', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35053:j_id35054'}
# 2024-07-10 13:33:10,929 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2468', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35051:j_id35052'}
# 2024-07-10 13:33:10,938 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2467', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35055:j_id35056'}
# 2024-07-10 13:33:10,947 - INFO - Submitting form to https://application.ocr.gov.np/faces/CompanyDetails.jsp with payload: {'j_id_jsp_826405674_6': 'j_id_jsp_826405674_6', 'j_id_jsp_826405674_6:registrationNumber': '2470', 'j_id_jsp_826405674_6:j_id_jsp_826405674_16': 'Search', 'javax.faces.ViewState': 'j_id35057:j_id35058'}
# 2024-07-10 13:33:10,993 - INFO - Form submitted successfully for registration number 2461.
# 2024-07-10 13:33:11,010 - INFO - Data inserted or updated successfully.
# 2024-07-10 13:33:11,083 - INFO - Form submitted successfully for registration number 2463.
# 2024-07-10 13:33:11,085 - INFO - Form submitted successfully for registration number 2465.
# 2024-07-10 13:33:11,100 - INFO - Form submitted successfully for registration number 2464.
# 2024-07-10 13:33:11,119 - INFO - Form submitted successfully for registration number 2466.
# 2024-07-10 13:33:11,138 - INFO - Form submitted successfully for registration number 2469.
# 2024-07-10 13:33:11,154 - INFO - Form submitted successfully for registration number 2468.
# 2024-07-10 13:33:11,168 - INFO - Form submitted successfully for registration number 2462.
# 2024-07-10 13:33:11,179 - INFO - Form submitted successfully for registration number 2467.

# %% [raw]
# #range 1 t0 100, in first 10, 4 form not submitted, others successful
# #In range 1 to 200, in first 10, 2 not submitted, others successful
# #range 1 to 300, 3 not submitted
# #range 1 to 500, no error
# #all good for all data
